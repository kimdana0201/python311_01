# %%
import pandas as pd

# %%
sample = pd.Series([10, 20, 30, 40, 50],
                   index=['가', '나', '다', '라', '마'])
sample
# Out:
# 가    10
# 나    20
# 다    30
# 라    40
# 마    50
# dtype: int64

# %%
import numpy as np

# %%
np.random.seed(20)
sample2 = pd.Series(np.random.randint(100, 200, size=(15,)))
sample2[sample2 <= 160]
# Out:
# 2     115
# 4     128
# 6     109
# 7     120
# 9     122
# 11    134
# 13    140
# dtype: int32

# %%
import pandas as pd
import numpy as np

# %%
sample3 = pd.Series(['apple', np.nan, 'banana', 'kiwi', 'gubong'],
                    index = ['가', '나', '다', '라', '마'])
sample3 = sample3.astype(object)
sample3
# Out:
# 가     apple
# 나       NaN
# 다    banana
# 라      kiwi
# 마    gubong
# dtype: object

# %%
sample3[sample3.notna()]
# Out:
# 가     apple
# 다    banana
# 라      kiwi
# 마    gubong
# dtype: object

# %%
sample3[sample3.isnull()]
# Out:
# 나    NaN
# dtype: object

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(0)
sample = pd.Series(np.random.randint(100, 200, size=(10,)))
sample.iloc[2:7]
# Out:
# 2    164
# 3    167
# 4    167
# 5    109
# 6    183
# dtype: int32

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(0)
sample2 = pd.Series(np.random.randint(100, 200, size=(10,)), 
                    index=list('가나다라마바사아자차'))
sample2.iloc[5:]
# Out:
# 바    109
# 사    183
# 아    121
# 자    136
# 차    187
# dtype: int32

# %%
np.random.seed(0)
sample2 = pd.Series(np.random.randint(100, 200, size=(10,)), 
                    index=list('가나다라마바사아자차'))
sample2.iloc[:3]
# Out:
# 가    144
# 나    147
# 다    164
# dtype: int32

# %%
np.random.seed(0)
sample2 = pd.Series(np.random.randint(100, 200, size=(10,)), 
                    index=list('가나다라마바사아자차'))
sample2.iloc[1:6]
# Out:
# 나    147
# 다    164
# 라    167
# 마    167
# 바    109
# dtype: int32
