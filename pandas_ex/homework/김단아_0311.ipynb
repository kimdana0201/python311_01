# %%
import pandas as pd
import numpy as np

col = ['food', 'price', 'rating']
data = ['KFC', 1000, '4.5'], ['McDonald', 2000, '3.9'], ['SchoolFood', 2500, '4.2']
df = pd.DataFrame(data=data, columns=col)
df
# Out:
#          food  price rating
# 0         KFC   1000    4.5
# 1    McDonald   2000    3.9
# 2  SchoolFood   2500    4.2

# %%
df[['food','rating']]
# Out:
#          food rating
# 0         KFC    4.5
# 1    McDonald    3.9
# 2  SchoolFood    4.2

# %%
df2 = df.rename(columns={'food':'place'})
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2 = df.rename(columns={'food':'place'})
#       2 df2
#
# NameError: name 'df' is not defined
